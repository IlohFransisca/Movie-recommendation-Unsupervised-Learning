# %% [markdown]
# <a id='Top'></a>
# # UNSUPERVISED CHALLENGE
#
# © Explore Data Science Academy
#
# ---
#
# # Team NM1 Unsupervised Predict Notebook
# ## Movie Recommendations
#
# ![WhatsApp Image 2024-01-16 at 10.39.44.jpeg](<attachment:WhatsApp Image 2024-01-16 at 10.39.44.jpeg>)

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# ## <a href=#one>1. Introduction</a>
# * <a href=#problemstament>1.1 Problem Statement</a>
# * <a href=#po>1.2 Project Objectives</a>
# * <a href=#dotrain_eda>1.3 Data Overview</a>
# * <a href=#StartingaCometexperiment>1.4 Comet experiment</a>
#
# ## <a href=#two>2. Import Necessary Libraries</a>
#
# ## <a href=#three>3. Loading Datasets</a>
#
#
# ## <a href=#four>4. Cleaning and PreProcessing (EDA)</a>
#
# ## <a href=#five>5. Exploratory Data Analysis</a>
#
# ## <a href=#six>6. Modelling</a>
#
# ## <a href=#seven>7. Conclusion</a>
#
# ## <a href=#ref>8. References</a>

# %% [markdown]
# <a id="one"></a>
# ### 1. INTRODUCTION
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# ### 1.1. Problem statement
# Back to Table of Contents
#
# In today's tech-driven world, recommender systems play a crucial role in individuals' daily content choices,
# with a specific focus on movie recommendations. The challenge is to develop and implement a recommendation
# algorithm using content or collaborative filtering. This algorithm aims to accurately predict user movie
# ratings by leveraging historical preferences, addressing EA's challenge to enhance the user experience in
# movie content recommendations.

# %% [markdown]
# ### 1.2. Project objectives
# Back to Table of Contents
#
# The goal is to develop and implement a robust recommendation algorithm, with primary objective of accurately predicting how users will rate movies they have not yet watched, based on their historical preferences
#
# Algorithm Development: Developing recommendation algorithm using either content or collaborative filtering methods.
#
# Prediction Accuracy: Predicting user ratings for movies that users have not yet watched.
#
# Historical Preference Analysis: Use past user preferences to improve the algorithm's ability to make accurate predictions.
#
# User Experience Enhancement: Meet EA's challenge to enhance overall user experience in movie recommendations.
#
# Scalability and Efficiency:Make the algorithm scalable for large datasets and optimize for real-time predictions.
#
# Evaluation Metrics: Use metrics like precision, recall, and F1-score to evaluate the recommendation algorithm's performance..
#
# Cross-Validation: Use cross-validation to check the reliability and applicability of the recommendation model.
#
# Documentation: Create detailed documentation with the algorithm's structure, parameters, and guidelines for future maintenance and enhancements.

# %% [markdown]
# <a id="dodf"></a>
#
# ### 1.3 Data Overview
#
# Millions of users of the online MovieLens movie recommendation service provided their 5-star ratings for this dataset, which comprises of several million ratings. In order to enhance the functionality of explicitly-based recommender systems, business and academic researchers have long used the MovieLens dataset.
#
# We'll be utilizing an enhanced, resampled, and unique version of the Movies dataset for this Predict in order to conduct a fair evaluation.
#
# #### I. Supplied Files
# * genome_scores.csv: a rating indicating how well movies match certain tag-related qualities.
#
# * genome_tags.csv: user-assigned tags for scores connected to the genome
#
# * imdb_data.csv: Using the links.csv file, more movie metadata is extracted from IMDB.
#
# * links.csv: File supplying a mapping between a related IMDB ID and TMDB ID and a Movies ID.
#
# * tags.csv: For each movie in the collection, a user-assigned number.
#
# * test.csv: The test split of the dataset. Contains user and movie IDs with no rating data.
#
# * train.csv: The dataset's training segment. Contains user and movie IDs and the ratings that go with them.
#
#
# >#### Additional Information
# The below information is provided directly from the Movies dataset description files:
#
# ### Ratings Data File Structure (train.csv)
# - The train.csv file contains all ratings. Following the header row, each line of this file contains one user's rating of one movie, in the following format:
#     - userId
#     - movieId
#     - rating
#     - timestamp
#
# - Within this file, the lines are arranged by userId first, then within user, by movieId.
#
# - A 5-star rating system is used, with half-star increments (0.5 stars - 5.0 stars).
#
# - Timestamps are seconds since midnight on January 1, 1970, Coordinated Universal Time (UTC).
#
# ### Tags Data File Structure (tags.csv)
# - The file tags.csv contains all of the tags. After the header row, each line in this file indicates a tag a user has applied to a particular video, and it is formatted as follows:
#     - userId
#     - movieId
#     - tag
#     - timestamp
#
# - Within this file, the lines are arranged by userId first, then within user, by movieId.
#
# - User-generated metadata about movies is created using tags. Typically, each tag consists of a single word or brief sentence. Each user decides what a given tag means, is worth, and serves for.
#
# - Timestamps show seconds since midnight on January 1, 1970, Coordinated Universal Time (UTC).
#
# ### Movies Data File Structure (movies.csv)
# - The movies.csv file contains movie-related data. Following the header row, each line in this file represents a single movie and is formatted as follows:
#     - movieId
#     - title
#     - genres
#
# - Genres are a pipe-separated list, and are selected from the following:
#     - Action
#     - Adventure
#     - Animation
#     - Children's
#     - Comedy
#     - Crime
#     - Documentary
#     - Drama
#     - Fantasy
#     - Film-Noir
#     - Horror
#     - Musical
#     - Mystery
#     - Romance
#     - Sci-Fi
#     - Thriller
#     - War
#     - Western
#     (no genres listed)
#
# ### Links Data File Structure (links.csv)
# - The file links.csv contains identifiers that may be used to link to various sources of movie data. This file's lines after the header row represent individual movies and are formatted as follows:
#     - movieId
#     - imdbId
#     - tmdbId
#
# - movieId is the movie identification that https://movies.org uses. For instance, https://movielens.org/movies/1 provides a link to the movie Toy Story.
#
# - The movie identification used by http://www.imdb.com is called imdbId. Toy Story, for instance, may be found at http://www.imdb.com/title/tt0114709.
#
# - tmdb
#
# - Id is the movie identification that https://www.themoviedb.org uses. Toy Story, for instance, may be found at https://www.themoviedb.org/movie/862.
#
# ### Tag Genome (genome-scores.csv and genome-tags.csv)
# - As previously mentioned, the tag genome encodes the degree to which movies display specific characteristics that are denoted by tags (atmospheric, thought-provoking, realistic, etc.). Using a machine learning algorithm on user-generated content, such as tags, ratings, and textual reviews, the tag genome was calculated.
# - Two files make up the genome. Movie-tag relevance information is presented in the following way in the file genome-scores.csv:
#     - movieId
#     - tagId
#     - relevance
# - The tag descriptions for the tag IDs in the genome file are provided in the second file, genome-tags.csv, in the following format:
#     - tagId
#     - tag

# %% [markdown]
# <a id="StartingaCometexperiment"></a>
#
# ### 1.4 Starting a Comet Experiment
#
# <img src="https://www.comet.ml/images/logo_comet_light.png" width="350" alt="Drawing" style="width: 350px;"/>
#
# - Comet offers data scientists and teams a self-hosted and cloud-based meta machine learning platform that enables tracking, comparing, explanatory, and model optimization.
# - Comet offers insights and data to construct stronger, more accurate AI models while enhancing productivity, collaboration, and visibility across teams. Comet is supported by thousands of users and several Fortune 100 firms.
# - Comet will be used by us as version control.

# %% [markdown]
# ### 1.5. Significance
# Back to Table of Contents
#
# A precise and strong solution to this challenge holds considerable economic potential for users.
# The system's capability to present content aligning with users' preferences not only generates
# revenue but also enhances their loyalty to the platform
#
# Benefits of recommendation system:
#
# Boost revenue and conversion rates."
# Increased user satisfaction
# Increased loyalty and top-of-mind awareness.
# Improved customer retention

# %% [markdown]
#  <a id="two"></a>
# ## 2. Import Necessary Libraries
# <a href=#cont>Back to Table of Contents</a>

# %%
# !pip install comet_ml
# Out:
# ...
#   Obtaining dependency information for comet_ml from https://files.pythonhosted.org/packages/77/38/0f218e8f66fb9fea1acb2c9872371bcd821b839c2ba4182700cf1bf31589/comet_ml-3.37.0-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 4.6 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for dulwich!=0.20.33,>=0.20.6 from https://files.pythonhosted.org/packages/3c/da/51281ef790c2117520cb52e65fa563c83df9dd8ae7353030e353af13e68f/dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.4/599.4 kB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 38.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.2
#     Uninstalling websocket-client-1.6.2:
# ...

# %%
#import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key
experiment = Experiment(
    api_key="b0uk0xjmnnpmZIsmRuHibUqPF",
    project_name="2307acds-team-nm1",
    workspace="kgasagogh",
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kgasagogh/2307acds-team-nm1/31680deb9ea1435c998b5f173842d886

# %%
# !pip install scikit-surprise

# %%
# Libraries for importing and loading data
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
import scipy as sp # <-- The sister of Numpy, used in our code for numerical efficientcy.
import seaborn as sns
from textwrap import wrap
import pickle

#visualization libraries
import plotly.express as px
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Entity featurization and similarity computation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# Install packages here

# Packages for data processing
import numpy as np
import pandas as pd
import datetime
from sklearn import preprocessing
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
from scipy.sparse import csr_matrix
import scipy as sp

# Package for timing code
import timeit


# Packages for visualization
import matplotlib
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# Style
import matplotlib.style as style
sns.set(font_scale=1.5)
#style.use('seaborn-pastel')
sns.set(style="whitegrid")
sns.set_style("dark")


# Packages for modeling
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import mean_squared_error, mean_absolute_error
from surprise import Reader
from surprise import Dataset
from surprise import KNNWithMeans
from surprise import KNNBasic
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering
from sklearn.neighbors import  NearestNeighbors
import heapq

# Performance Evaluation
from surprise import accuracy
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from surprise.model_selection import GridSearchCV, cross_validate, train_test_split
from time import time

# Package to suppress warnings
import warnings
warnings.filterwarnings("ignore")

# Packages for saving models
import pickle

#import cufflinks as cf
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# Packages for Randomisation
import random

sns.set(style='whitegrid', palette='muted',
        rc={'figure.figsize': (15,10)})

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

# Data Preprocessing
import random
from time import time
#import cufflinks as cf
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
from sklearn.preprocessing import StandardScaler
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

# Models
#from surprise import Reader, Dataset
#from surprise import SVD, NormalPredictor, BaselineOnly, NMF, SlopeOne, CoClustering
from sklearn.metrics.pairwise import cosine_similarity


# Libraries used during sorting procedures.
import operator # <-- Convienient item retrieval during iteration
import heapq # <-- Efficient sorting of large lists

# Setting global constants to ensure notebook results are reproducible

RANDOM_STATE = 42


import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %% [markdown]
# <a id="three"></a>
# ### 3. Loading Datasets
# <a href=#cont>Back to Table of Contents</a>

# %%
train = pd.read_csv('/kaggle/input/dataset/train.csv')
test = pd.read_csv('/kaggle/input/dataset/test.csv')
genome_scores = pd.read_csv('/kaggle/input/dataset/genome_scores.csv', index_col='movieId')
genome_tags = pd.read_csv('/kaggle/input/dataset/genome_tags.csv')
imdb_data = pd.read_csv('/kaggle/input/dataset/imdb_data.csv')
links = pd.read_csv('/kaggle/input/dataset/links.csv')
movies = pd.read_csv('/kaggle/input/dataset/movies.csv')
tags = pd.read_csv('/kaggle/input/dataset/tags.csv')
sample_submission = pd.read_csv('/kaggle/input/dataset/sample_submission.csv')

# %%
# Set option to display all columns
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# <a id="four"></a>
# ## 4. Cleaning and PreProcessing
# <a href=#cont>Back to Table of Contents</a>

# %%
def print_data_shapes():
    dataframes = {
        "Train": train,
        "Movie": movies,
        "Imdb": imdb_data,
        "Genome_tags": tags,
        "Genome_scores": genome_scores,
        "Tags": tags,
        "Links": links,
        "Test": test
    }

    # Create a dictionary to store data properties
    df_stored_data = {}

    # Populate the dictionary with data properties
    for name, dataframe in dataframes.items():
        df_stored_data[name] = {"Rows": dataframe.shape[0], "Columns": dataframe.shape[1]}

    # Create a DataFrame from the dictionary
    df_stored_data = pd.DataFrame.from_dict(df_stored_data, orient='index')

    # Sort the DataFrame by the number of rows in descending order
    df_stored_data = df_stored_data.sort_values(by='Rows', ascending=False)

    print(df_stored_data)

print_data_shapes()
# Out:
#                    Rows  Columns
# Genome_scores  15584448        2
# Train          10000038        4
# Test            5000019        2
# Genome_tags     1093360        4
# Tags            1093360        4
# Movie             62423        3
# Links             62423        3
# Imdb              27278        6

# %%
def display_data_heads():
    dataframes = {
        "Train": train,
        "Movie": movies,
        "Imdb": imdb_data,
        "Genome_tags": tags,
        "Genome_scores": genome_scores,
        "Tags": tags,
        "Links": links,
        "Test": test
    }

    for name, dataframe in dataframes.items():
        print(f"\nHead of {name} data:")
        display(dataframe.head())

display_data_heads()
# Out:
# Head of Train data:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837
# Head of Movie data:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# Head of Imdb data:
#    movieId  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#
# ...

# %% [markdown]
# ### Observations
#
# #### Movies:
# movieId : Identify the movies that are watched
#
# title : Entered manually or imported from https://www.themoviedb.org/, and include the year of release in parentheses. Errors and inconsistencies may exist in these titles.
#
# genres: They are pipe-separated list, and are selected from the following:
#
# - Action
# - Adventure
# - Animation
# - Children's
# - Comedy
# - Crime
# - Documentary
# - Drama
# - Fantasy
# - Film-Noir
# - Horror
# - Musical
# - Mystery
# - Romance
# - Sci-Fi
# - Thriller
# - War
# - Western
# - (no genres listed)
#
# tag : tag descriptions for the tag IDs in the genome file, User-generated metadata about movies. Each tag is typically a single word or short phrase. The meaning, value, and * purpose of a particular tag is determined by each user.
#
# UserId movieId : Identifier for movies used
#
# rating : Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars)
#
# timestamp: represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970
#
# #### Links:
#
# * movieId : Identifier for movies used by https://movielens.org
# * imdbId : Identifier for movies used by http://www.imdb.com
# * tmdbId : An identifier for movies used by https://www.themoviedb.org.
#
# ### Data Definitions
# ##### Numeric
#
# - budget: - (continuous) dollar cost of production of the movie.
# - rating: - (discrete) users rating of a movie from. TARGET
# - relevance: - (continuous) measure (0-1) of the relevance of a genome tag to the movie, where 1 impies 100% relevance.
# - runtime: - (continuos) movie duration in minutes.
# - timestamp: - (continuous) the time at which a user rated the movie.
#
# ##### Categorical
#
# - director: - (nominal) the person who controls the making of a film and supervises the actors and technical crew.
# - genres: - (nominal) the style or category of the movie. A movie may belong to multiple (up to nineteen) genres, or may be absent a genre listing.
# - imdbId: - (nominal) unique indentifying key for each IMBD entry. Can also be used in conjunction with the TMDB API.
# - movieId: - (nominal) a unique identifier for each movie. There are 48,213 unique movies.
# - plot_keywords: - (nominal) key words used to identify characteristics of a movie's storyline.
# - tag: - (nominal) genome label
# - tagId: - (nominal) unique genome identifier.
# - tmdbId: - (nominal) unique identifier that works in conjunction with the TMDB API.
# - title: - (nominal) the unique title identifying the movie. Included is a year of release enclosed in parenthesis at the end of the title.
# - title_cast: - (nominal) the actors of the main characters in the movie. This does not include extras.
# - userId: - (nominal) a unique identifier for each user. There are 162,541 unique users.

# %% [markdown]
# ### Checking for duplicated data

# %%
# Checking for unique users and movieId's in the train dataset
unique_users = train['userId'].nunique()
unique_movies = train['movieId'].nunique()
duplicated_entries = train[train.duplicated()].count().sum()

print(f"There are {unique_users} unique users and {unique_movies} unique movies in the train dataset with {duplicated_entries} duplicated entries.")
# Out:
# There are 162541 unique users and 48213 unique movies in the train dataset with 0 duplicated entries.

# %% [markdown]
# ### Checking for missing Values

# %%
print("Train: ")
print(str(train.isnull().sum()))
print("============")
print("Test: ")
print(str(test.isnull().sum()))
print("============")
print("Movies: ")
print(str(movies.isnull().sum()))
print("============")
print("Links: ")
print(str(links.isnull().sum()))
print("============")
print("IMDB: ")
print(str(imdb_data.isnull().sum()))
print("============")
print("Genome scores: ")
print(str(genome_scores.isnull().sum()))
print("============")
print("Genome tags: ")
print(str(genome_tags.isnull().sum()))
# Out:
# Train:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64
# ...
# Test:
# userId     0
# movieId    0
# dtype: int64
# ...
# Movies:
# movieId    0
# title      0
# genres     0
# dtype: int64
# ...
# Links:
# movieId      0
# imdbId       0
# tmdbId     107
# dtype: int64
# ...
# IMDB:
# movieId              0
# title_cast       10068
# director          9874
# runtime          12089
# budget           19372
# plot_keywords    11078
# dtype: int64
# ...
# Genome scores:
# tagId        0
# relevance    0
# dtype: int64
# ...
# Genome tags:
# tagId    0
# tag      0
# dtype: int64

# %%
imdb_data.dropna(inplace=True)
links.dropna(inplace=True)

# %% [markdown]
# ### Calcuating Rating avarage and count

# %%
merged_movie_ratings = (
    train.groupby('movieId')
    .agg({'rating': 'mean', 'userId': 'count'})
    .rename(columns={'rating': 'rating_avg', 'userId': 'rating_count'})
    .reset_index()
    .merge(movies)
    .head(10)
)

merged_movie_ratings
# Out:
#    movieId  rating_avg  rating_count                               title  \
# 0        1    3.889971         23062                    Toy Story (1995)
# 1        2    3.263414          9654                      Jumanji (1995)
# 2        3    3.132325          4727             Grumpier Old Men (1995)
# 3        4    2.878099           968            Waiting to Exhale (1995)
# 4        5    3.059165          4648  Father of the Bride Part II (1995)
# 5        6    3.857906          9828                         Heat (1995)
# 6        7    3.381459          4838                      Sabrina (1995)
# 7        8    3.052209           498                 Tom and Huck (1995)
# 8        9    3.010533          1519                 Sudden Death (1995)
# 9       10    3.414240         11369                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# ...

# %% [markdown]
# ### checking for null values in genres

# %%
null_values_count = movies['genres'].isna().sum()

# Print the result
print("Number of null values in the 'genres' column:", null_values_count)
# Out:
# Number of null values in the 'genres' column: 0

# %% [markdown]
# ### Converting genres to list

# %%
merged_movie_ratings.genres = merged_movie_ratings.genres.str.split('|')
merged_movie_ratings.head(5)
# Out:
#    movieId  rating_avg  rating_count                               title  \
# 0        1    3.889971         23062                    Toy Story (1995)
# 1        2    3.263414          9654                      Jumanji (1995)
# 2        3    3.132325          4727             Grumpier Old Men (1995)
# 3        4    2.878099           968            Waiting to Exhale (1995)
# 4        5    3.059165          4648  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
# Capturing Tags only if its relevance is higher than 80% to a movie
gs= genome_scores[genome_scores['relevance'] > 0.80]
gs.head(10)
# Out:
#          tagId  relevance
# movieId
# 1           29    0.89375
# 1           63    0.94725
# 1           64    0.98425
# 1          186    0.95475
# 1          193    0.81450
# 1          203    0.90375
# 1          204    0.95975
# 1          215    0.81500
# 1          244    0.99875
# 1          278    0.84200

# %% [markdown]
# **creating the release year column**

# %%
df = imdb_data[['movieId','title_cast','director', 'plot_keywords']]
df = df.merge(movies[['movieId', 'genres', 'title']], on='movieId', how='inner')
#Add colummn for release year
df['year'] = df['title'].str.extract(r"\((\d+)\)", expand=False)
df.head()
# Out:
#    movieId  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#
#                                                                                                                                                                                                                           title_cast  \
# 0                                 Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette|Jack Angel|Spencer Aste
# 1  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup
# ...

# %% [markdown]
# ### Checking for missing values on the merged movies with our train data
#
# Checking for missing and Merging of the dataset
#
# Now that we have a basic understanding of the data we are working with, we merge the sets below for more in depth analysis in the EDA section. Inorder to play along with our data and before data processing. Let's merge some of our data to see how it work out.

# %%
# Merge the train and movies data
merged_data = train.merge(movies, on='movieId')

# Viewing the 1st 5 rows
merged_data.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
# 3  120490    57669     4.5  1408228517  In Bruges (2008)
# 4   50616    57669     4.5  1446941640  In Bruges (2008)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller

# %%
# Checking for nulls
merged_data.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# title        0
# genres       0
# dtype: int64

# %%
# Merging table1 dataframe and Imdb data
merged_data_imdb = merged_data.merge(imdb_data, on='movieId')

# Viewing the 1st 5 rows
merged_data_imdb.head()
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
# 3  120490    57669     4.5  1408228517  In Bruges (2008)
# 4   50616    57669     4.5  1446941640  In Bruges (2008)
#
#                         genres  \
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
# 3  Comedy|Crime|Drama|Thriller
# 4  Comedy|Crime|Drama|Thriller
#
#                                                                                                                                                                                                              title_cast  \
# ...

# %%
# Checking for nulls
merged_data_imdb.isnull().sum()
# Out:
# userId           0
# movieId          0
# rating           0
# timestamp        0
# title            0
# genres           0
# title_cast       0
# director         0
# runtime          0
# budget           0
# plot_keywords    0
# dtype: int64

# %%
merged_data_imdb.shape
merged_data_imdb.dtypes
# Out:
# userId             int64
# movieId            int64
# rating           float64
# timestamp          int64
# title             object
# genres            object
# title_cast        object
# director          object
# runtime          float64
# budget            object
# plot_keywords     object
# dtype: object

# %%
# Merge train with movies to join movie titles and ratings
ratings = train.merge(movies, on='movieId', how='inner')
ratings['title']=ratings['title'].str.replace('\d+', '')
ratings['title']=ratings['title'].str.replace('(','').str.replace(')','')
ratings['title']=ratings['title'].str.strip()
ratings.drop('timestamp', axis=1, inplace=True)

# %%
# Extract 'movieId' and 'genres' columns from df_movies
movies_genres = movies[['movieId', 'genres']]

# Use the 'genres' column to create a new DataFrame with each genre in a separate row
movies_genres = movies_genres.assign(genres=movies_genres['genres'].str.split('|')).explode('genres')

# Reset the index to get a clean DataFrame
movies_genres.reset_index(drop=True, inplace=True)

movies_genres.head()
# Out:
#    movieId     genres
# 0        1  Adventure
# 1        1  Animation
# 2        1   Children
# 3        1     Comedy
# 4        1    Fantasy

# %% [markdown]
#  <a id="five"></a>
# ## 5. Exploratory Data Analysis
# <a href=#cont>Back to Table of Contents</a>

# %%
#dropping the timestamp column because we don't need it
df_train = train.drop('timestamp', axis = 1)
merged_movie_ratings = pd.merge(movies, df_train)
merged_movie_ratings.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0  158849     5.0
# 1   97203     5.0
# 2  161871     3.0
# 3   45117     4.0
# 4   27431     5.0

# %% [markdown]
# ### Data visualisaton

# %% [markdown]
# #### Ratings

# %%
fig, ax = plt.subplots(figsize=(14, 8))
sns.histplot(data=df_train, x='rating', ax=ax, bins=10, kde=False)
ax.set_title('Frequency Distribution of Rating Scores', fontsize=20)
ax.set_xlabel('Rating')
ax.set_ylabel('Count')
plt.show()

# %%
# Count how many ratings are in each category (1 star, 2 star, ect)
grouped = pd.DataFrame(ratings.groupby(['rating'])['title'].count())
grouped.rename(columns={'title':'rating_count'}, inplace=True)

# %%
# Creating plots
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(122)

# Create colour palette
labels = ['0.5 Star', '1 Stars', '1.5 Stars', '2 Stars', '2.5 Stars', '3 Star', '3.5 Stars', '4 Stars', '4.5 Stars', '5 Stars']
theme = plt.get_cmap('Blues')
ax.set_prop_cycle("color", [theme(1. * i / len(labels))
                                 for i in range(len(labels))])
sns.set(font_scale=1.25)

# Create pie chart
pie = ax.pie(grouped['rating_count'],
                 autopct='%1.1f%%',
                 startangle=20,
                 pctdistance=1.115)

# Display donut plot with legend
plt.legend(pie[0], labels, loc="lower left")
ax.set_title('Rating distribution viewers rating\n', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observation
#
# * Most ratings in the viewers rating dataset are 4 stars, making up the biggest chunk with 26.5%. The next popular rating is 5 stars, representing 14.5% of all ratings. The smallest portion goes to 0.5 stars, making up only 1.6%. About 12.9% of ratings fall between 2 and 0.5 stars.

# %% [markdown]
# #### Genres

# %%
# Get the most common genres and their counts
genre_counts = movies_genres['genres'].value_counts(ascending=False)

# Plot the genres from most common to least common
plt.figure(figsize=(15, 10))
sns.barplot(x=genre_counts, y=genre_counts.index, palette='brg')
plt.title('Most Common Genres\n', fontsize=20)
plt.xlabel('Count')
plt.ylabel('Genres')
plt.show()

# %% [markdown]
# #### Observations
#
# * The most frequently occurring genre in the database is drama. Approximately 5000 films lack genres. We can use the IMDB and TMDB IDs in conjunction with the APIs to fill in the blanks. Furthermore, IMAX is a proprietary system for mass viewings rather than a genre.

# %%
# Combine all genres into a single string
all_genres = ' '.join(movies_genres['genres'])

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_genres)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### Observations
#
# * A word cloud visually represent the frequency of different genres in the dataset.
# The size of each genre in the word cloud corresponds to its frequency.

# %%
def most_watched(input_df):
    """"
    This function creates a plot showing the popularity of each genre
    over the last 50 years.

    Input: input_df
           datatype: DataFrame

    Output: None

    """
    # Create a copy of the input dataframe and merge it to the movies dataframe
    df = input_df.copy()
    df = df.merge(movies,on='movieId',how='left')

    # Create an empty dataframe
    b = pd.DataFrame()

    # Extract the timestamps and genres
    timestamps = [timestamp for timestamp in df.timestamp]
    all_genres = set(','.join([genres.replace('|',',') for genres in df.genres]).split(','))

    # Get the number of ratings for each genre for each year since 1970
    for index,genre in enumerate(all_genres):
        a = pd.Series([int((timestamps[i]/31536000)+1970) for i,x in enumerate(df.genres) if genre in x])
        a = a.value_counts()
        b = pd.concat([b,pd.DataFrame({genre:a})],axis=1)

    # Plot the trends for each genre on the same line graph
    plt.figure(figsize=(20,10))
    plot = sns.lineplot(data=b, dashes=False)

    # Add plot labels
    plt.title('Trends in genre popularity',fontsize=20)
    plt.xlabel('Years', fontsize=15)
    plt.ylabel('Number of ratings', fontsize=15)

    plt.show()

    return

most_watched(train)

# %% [markdown]
# #### Observations
#
# * The majority of genres exhibit a similar trend, with a significant uptick in 2015. This could be due to an increase in users or an increase in the quantity of films released.
# * We also notice that the number of films graded in each genre sharply increased in 1996 before dramatically declining over the next two years.
# * It's also important to note that during the past five years, the number of movie ratings has decreased overall.

# %% [markdown]
# #### Cast

# %%
# Split the 'title_cast' column into individual cast members
imdb_data['cast_members'] = imdb_data['title_cast'].str.split('|')

# Flatten the list of cast members
flat_cast_list = [cast_member for sublist in imdb_data['cast_members'].dropna() for cast_member in sublist]

# Create a DataFrame to count the occurrences of each cast member
cast_counts = pd.Series(flat_cast_list).value_counts().reset_index()
cast_counts.columns = ['Cast Member', 'Count']

# Plotting a bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='Cast Member', data=cast_counts.head(10))  # Displaying the top 10 cast members
plt.title('Top Cast Members in the Dataset')
plt.xlabel('Count')
plt.ylabel('Cast Member')
plt.show()

# %% [markdown]
# #### Directors

# %%
# Count the number of movies directed by each director
director_counts = imdb_data['director'].value_counts().reset_index()
director_counts.columns = ['Director', 'Number of Movies']

# Plotting a bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='Number of Movies', y='Director', data=director_counts.head(10))  # Displaying the top 10 directors
plt.title('Number of Movies Directed by Each Director')
plt.xlabel('Number of Movies')
plt.ylabel('Director')
plt.show()

# %% [markdown]
# #### Observation
#
# The most common directors are Lus Besson, Woody Allen and Stephen King and Ki-duk Kim. William Shakespear and Stephen King are writers, not directors. This is somehting to keep in mind when modelling.

# %% [markdown]
# #### Year

# %%
# Extract the release year from the movie titles
import re


ratings['release_year'] = ratings.title.map(lambda x: re.findall('\d\d\d\d', x))
ratings.release_year = ratings.release_year.apply(lambda x: np.nan if not x else int(x[-1]))
years =  pd.DataFrame(ratings.groupby(['release_year'])['title'].count())
years.rename(columns={'title':'movies released'}, inplace=True)

# Plot the number of movies released per year
plt.figure(figsize=(10,5))
plot = sns.lineplot(data=years, dashes=False, legend=False, palette='Blues')

# Add figure labels
plt.xlabel('Years', fontsize=15)
plt.ylabel('Number of rated released', fontsize=15)
plt.title('Movies rated per year\n', fontsize=20)

plt.show()

# %% [markdown]
# #### Observation
#
# * It is observed that more movies have been released as we progressed with in 20th century with biggest increase from the 1980's to the 2000's. This could be because the increase in technological advancements like the introduction of motion picture projectors and more people having access to the entertainment in theatres.

# %% [markdown]
#  <a id="six"></a>
# ## 6. Modelling
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# #### Content Based Filtering
#
# * Content-based filtering is a recommendation system approach that suggests items to users based on the features or attributes of those items and the user's preferences. It creates a profile for each user and recommends items that are similar to what the user has liked before. For example, in a movie recommendation system, it might suggest movies with similar genres, directors, or actors based on the user's past interactions.

# %%
df = imdb_data[['movieId','title_cast','director', 'plot_keywords']]
df = df.merge(movies[['movieId', 'genres', 'title']], on='movieId', how='inner')
#Add colummn for release year
df['year'] = df['title'].str.extract(r"\((\d+)\)", expand=False)
df.head()
# Out:
#    movieId  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#
#                                                                                                                                                                                                                           title_cast  \
# 0                                 Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette|Jack Angel|Spencer Aste
# 1  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup
# ...

# %%
# List of the columns we want to use to create our corpus
columns = ['title_cast', 'director', 'plot_keywords', 'genres']

# Create a new column 'corpus' by combining selected columns
df['corpus'] = df[columns].apply(lambda x: ' '.join(x), axis=1)

# Set 'movieId' as the index
df.set_index('movieId', inplace=True)

# Drop the columns we don't need anymore to preserve memory
df.drop(columns=columns, inplace=True)

df.head()
# Out:
#                                       title  year  \
# movieId
# 1                          Toy Story (1995)  1995
# 2                            Jumanji (1995)  1995
# 3                   Grumpier Old Men (1995)  1995
# 4                  Waiting to Exhale (1995)  1995
# 5        Father of the Bride Part II (1995)  1995
#
#                                                                                                                                                                                                                                                                                                                                     corpus
# movieId
# ...

# %% [markdown]
# #### using corpus
#
# * A "corpus" is employed to process and analyze textual data in our recommender. It serves essential purposes such as tokenization (breaking text into words) and frequency analysis to identify common terms.

# %%
#creating a count for the convertion of the corpus to a bag of words

cv = CountVectorizer()
count_matrix = cv.fit_transform(df['corpus'])

# %%
# Cosine matrix
# Cosine similarity is a metric used to measure how similar the documents are irrespective of their size.

cos_sim = cosine_similarity(count_matrix, count_matrix)
print(cos_sim.shape)
cos_sim[:3]
# Out:
# (6493, 6493)
# array([[1.        , 0.06063391, 0.06482037, ..., 0.02160679, 0.04270814,
#         0.01960784],
#        [0.06063391, 1.        , 0.02227177, ..., 0.        , 0.        ,
#         0.        ],
#        [0.06482037, 0.02227177, 1.        , ..., 0.        , 0.02353104,
#         0.02160679]])

# %%
# With our content similarity matrix computed, we're now ready to make some recommendations.
# We will generate movies similar to one which we prompt the system with.

def get_recommendations(title, n):
    """
    This function gets the top n recommended movies based on the
    title of the movie input by the user

    Input: title
           Datatype: str

           n = input
           Datatype: int
    """

    # Extract the movie titles and reset the index
    titles = df['title']
    df1 = df.reset_index()

    # Get the index of the input movie title
    idx = df1[df1['title'] == title].index[0]

    # Get the similarity scores of the top n movies most similar to the user input
    sim_scores = list(enumerate(cos_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:n+1]  # Adjusted to include the top n movies

    # Extract the indices of the top n most similar movies
    movie_indices = [i[0] for i in sim_scores]

    # Return the titles of the top n most similar movies
    return titles.iloc[movie_indices]

# Example usage
get_recommendations('Jumanji (1995)', 10)
# Out:
# movieId
# 2355                               Bug's Life, A (1998)
# 40851                                    Zathura (2005)
# 3512                                Return to Me (2000)
# 3754     Adventures of Rocky and Bullwinkle, The (2000)
# 65088                            Bedtime Stories (2008)
# 87222                            Kung Fu Panda 2 (2011)
# 3157                               Stuart Little (1999)
# 4686                      Weekend at Bernie's II (1993)
# 1681                 Mortal Kombat: Annihilation (1997)
# 8938                                   Tarnation (2003)
# Name: title, dtype: object

# %% [markdown]
# ### Collaborative filtering

# %% [markdown]
# #### modelling using Surprise MovieLens

# %% [markdown]
# #### KNN Model

# %%
from surprise import KNNBasic
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split

# Load the movielens-100k dataset
data = Dataset.load_builtin('ml-100k')

#time the experiment
start = timeit.default_timer()

# sample random trainset and testset
# test set is made of 25% of the ratings.
trainset, testset = train_test_split(data, test_size=.25)

# We'll use the SVD++ algorithm here
algorithm = KNNBasic()

# Train the algorithm on the trainset, and predict ratings for the testset
algorithm.fit(trainset)
predictions = algorithm.test(testset)

# Then compute RMSE
KNN_RMSE = accuracy.rmse(predictions)
print('KNN_RMSE = ' + str(KNN_RMSE))

#Calculate + print experiment time
stop = timeit.default_timer()
execution_time_KNN = stop - start
print("Program Executed in "+str(execution_time_KNN) + " seconds") # It returns time in seconds
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n]
#  y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9908
# KNN_RMSE = 0.9907702402727361
# Program Executed in 4.159746984999856 seconds

# %% [markdown]
# #### SlopeOne Model

# %%
# Time the experiment
start = timeit.default_timer()
trainset, testset = train_test_split(data, test_size=.25)

# We'll use the SlopeOne algorithm here
algo = SlopeOne()

# Train the algorithm on the trainset, and predict ratings for the testset
algorithm.fit(trainset)
predictions = algorithm.test(testset)

# Then compute RMSE
SlopeOne_RMSE = accuracy.rmse(predictions)
print('SlopeOne_RMSE = ' + str(SlopeOne_RMSE))

stop = timeit.default_timer()
execution_time_SlopeOne = stop - start
print("Program Executed in "+str(execution_time_SlopeOne) + " seconds")
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9823
# SlopeOne_RMSE = 0.9822673407567928
# Program Executed in 4.297633700999995 seconds

# %% [markdown]
# #### CoClustering Model

# %%
from surprise import CoClustering

# Time the experiment
start = timeit.default_timer()
trainset, testset = train_test_split(data, test_size=.25)

# We'll use the CoClustering algorithm here
algorithm = CoClustering()

# Train the algorithm on the trainset, and predict ratings for the testset
algorithm.fit(trainset)
predictions = algorithm.test(testset)

# Then compute RMSE
CoClustering_RMSE = accuracy.rmse(predictions)
print('CoClustering_RMSE = ' + str(CoClustering_RMSE))
stop = timeit.default_timer()
execution_time_CoClustering = stop - start
print("Program Executed in "+str(execution_time_CoClustering) + " seconds")
# Out:
# RMSE: 0.9683
# CoClustering_RMSE = 0.9682632798387623
# Program Executed in 2.1769629060004263 seconds

# %% [markdown]
# #### Singular value decomposition - SVD Model

# %%
from surprise import SVD

# time the experiment
start = timeit.default_timer()

trainset, testset = train_test_split(data, test_size=.25)

# We'll use the SVD algorithm.
algo = SVD()

# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

SVD_RMSE = accuracy.rmse(predictions)
print('SVD_RMSE = ' + str(SVD_RMSE))

stop = timeit.default_timer()
execution_time_SVD = round((stop - start), 2)
print("Program Executed in " + str(execution_time_SVD) + " seconds")
# Out:
# RMSE: 0.9416
# SVD_RMSE = 0.9415853267287309
# Program Executed in 1.5 seconds

# %% [markdown]
# #### Comparison of the models RMSE and the runtime

# %%
import matplotlib.pyplot as plt

# Data
models = ['KNN', 'SlopeOne', 'CoClustering', 'SVD']
runtimes = [execution_time_KNN, execution_time_SlopeOne, execution_time_CoClustering, execution_time_SVD]
rmse_values = [KNN_RMSE, SlopeOne_RMSE, CoClustering_RMSE, SVD_RMSE]

# Plotting
fig, ax1 = plt.subplots()

# Bar plot for runtime
ax1.bar(models, runtimes, color='b', alpha=0.7, label='Runtime')
ax1.set_xlabel('Models')
ax1.set_ylabel('Runtime (seconds)', color='b')
ax1.tick_params('y', colors='b')

# Creating a second y-axis for RMSE
ax2 = ax1.twinx()
ax2.plot(models, rmse_values, color='r', marker='o', label='RMSE')
ax2.set_ylabel('RMSE', color='r')
ax2.tick_params('y', colors='r')

# Title and legend
plt.title('Runtime and RMSE Comparison')
fig.tight_layout()
plt.legend(loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# #### Creating a reader for the data
# * The Reader class in Surprise provides a way to specify the format of the data, especially when loading data from a pandas dataframes and external files.

# %%
# Load the dataset and preprocess
train_df = pd.read_csv('/kaggle/input/dataset/train.csv')
model_testing_df = train_df.sample(500000)
df = pd.DataFrame(model_testing_df)
del df['timestamp']

# A reader is still needed but only the rating_scale param is required.
reader = Reader(rating_scale=(0, 5))

# The columns must correspond to user id, item id, and ratings (in that order).
data = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)

# Run on the subset of the train data to illustrate the model performance
trainset, testset = train_test_split(data, test_size=.25)

# %% [markdown]
# #### GridSearchCV for SVD Hyperparameter Tuning:
# * GridSearchCV automates the search for optimal hyperparameters for the SVD (Singular Value Decomposition) collaborative filtering algorithm. The provided hyperparameter grid, including parameters like n_epochs and n_factors, is exhaustively explored to find the combination that minimizes the RMSE (Root Mean Squared Error) on the training dataset. This process ensures better model performance and generalization to new data. Accuracy is used as the metric to evaluate and select the best hyperparameters.

# %%
from surprise.model_selection import GridSearchCV
from surprise import dataset

# Define a grid of parameters for the SVD algorithm
param_grid = {
    'n_epochs': [30, 40, 50],
    'n_factors': [200, 300, 400],
    'init_std_dev': [0.001, 0.005, 0.05, 0.1],
    'random_state': [42]
}

# Create a GridSearchCV object for the SVD algorithm
grid_SVD = GridSearchCV(
    SVD,               # SVD algorithm from Surprise library
    cv=5,              # 5-fold cross-validation
    measures=['rmse'], # Use RMSE as the evaluation metric
    param_grid=param_grid,  # Grid of parameters to search
    n_jobs=-1,         # Use all available CPU cores for parallel processing
    joblib_verbose=10  # Verbose level for joblib parallel processing
)

# Fit the GridSearchCV object on the dataset
grid_SVD.fit(data)

# Print the best score and corresponding parameters
print('Best Score is: ')
print(grid_SVD.best_score['rmse'])
print('Best Parameters are: ')
print(grid_SVD.best_params['rmse'])
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.

# %% [markdown]
# #### SVD Algorithm Training and Evaluation

# %%
#allows us to train on the whole dataset
trainset = data.build_full_trainset()

#SVD algorithm.
algorithm = SVD(n_epochs = 50, n_factors = 400, init_std_dev = 0.001, random_state=42)

# Train the algorithm on the trainset, and predict ratings for the testset
algorithm.fit(trainset)

# sample random trainset and testset
# test set is made of 25% of the ratings.
trainset, testset = train_test_split(data, test_size=.25)

# Use the SVD algorithm.
algo_svd = SVD()

# Train the algorithm on the trainset, and predict ratings for the testset
algo_svd.fit(trainset)
predictions = algo_svd.test(testset)

# Compute RMSE
accuracy.rmse(predictions)

# %% [markdown]
# #### Engineering and data trimming

# %%
from surprise.model_selection import train_test_split, GridSearchCV
from IPython.display import display

# Load the training data from the CSV file
train_df = pd.read_csv('/kaggle/input/dataset/train.csv')

# Remove outliers in userID in train_df
display(train_df.info())
display(train_df.head(3))
train_df.drop(train_df.index[train_df['userId'] == 72315], inplace=True)
train_df = train_df.reset_index(drop=True)

# Use a subset of the train data to illustrate the model performance
model_testing_df = train_df.sample(500000)
df = pd.DataFrame(model_testing_df)
del df['timestamp']

# A reader is still needed, but only the rating_scale param is required.
reader = Reader(rating_scale=(0, 5))

# The columns must correspond to user id, item id, and ratings (in that order).
data = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)

# Parameter grid for the GridSearchCV
param_grid = {
    'n_epochs': [30, 40, 50],
    'n_factors': [200, 300, 400],
    'init_std_dev': [0.001, 0.005, 0.05, 0.1],
    'random_state': [42]
}

# GridSearchCV for the SVD algorithm
grid_SVD = GridSearchCV(SVD, cv=5, measures=['rmse'], param_grid=param_grid, n_jobs=-1, joblib_verbose=10)
grid_SVD.fit(data)
print('Best Score is: ')
print(grid_SVD.best_score['rmse'])
print('Best Parameters are: ')
print(grid_SVD.best_params['rmse'])

# Allows us to train on the whole dataset
trainset = data.build_full_trainset()

# SVD algorithm.
algorithm = SVD(n_epochs=50, n_factors=400, init_std_dev=0.001, random_state=42)

# Train the algorithm on the trainset
algorithm.fit(trainset)

# Sample random trainset and testset
# Test set is made of 25% of the ratings.
trainset, testset = train_test_split(data, test_size=.25)

# Use the SVD algorithm.
algo_svd = SVD()

# Train the algorithm on the trainset, and predict ratings for the testset
algo_svd.fit(trainset)
predictions = algo_svd.test(testset)

# Compute RMSE
accuracy.rmse(predictions)

# %% [markdown]
# #### Comet experience

# %%
#experiment.log_parameters({"model_type": "SVD"})
#experiment.log_metrics({"RMSE": accuracy.rmse(predictions)})
#experiment.end()

# %% [markdown]
# #### Kaggle csv for submission

# %%
# Load the test dataset
test_df = pd.read_csv('Data/test.csv')

# Set initial rating to 0 for predictions
test_df.loc[:, 'rating'] = 0

# Use Surprise's load_from_df function to load the test dataset for predictions
test_processed = Dataset.load_from_df(test_df[['userId', 'movieId', 'rating']], reader)

# Train-test split with test size equal to 1 (we will use the whole dataset for predictions)
# Set shuffle to False to maintain the original order
NA, test = train_test_split(test_processed, test_size=1.0, shuffle=False, random_state=42)

# Make predictions using the trained algorithm
predictions = algo.test(test)

# Extract predicted ratings from the predictions
ratings = [i.est for i in predictions]

# Now 'ratings' contains the predicted ratings for the test dataset

# %%
# Display the head of the sample_submission DataFrame
display(sample_submission.head())

# Create a new 'Id' column in the test_df DataFrame using string concatenation
test_df['Id'] = test_df[['userId', 'movieId']].astype(str).agg('_'.join, axis=1)

# Display the modified test_df DataFrame with the new 'Id' column
test_df

# Change the 'rating' column in test_df to contain the predicted ratings
test_df['rating'] = ratings

# Drop the 'userId' and 'movieId' columns from test_df
test_df.drop(['userId', 'movieId'], axis=1, inplace=True)

# Display the final test_df DataFrame with the updated 'rating' column
display(test_df)

# %%
# Create a temporary variable 'temp_rating' to hold the values of 'rating'
test_df['temp_rating'] = test_df['rating']

# Replace the values in 'rating' with the values in 'R'
test_df['rating'] = test_df['Rate']

# Replace the values in 'R' with the original values from 'rating'
test_df['Rate'] = test_df['temp_rating']

# Delete the temporary variable 'temp_rating'
del test_df['temp_rating']

# Display the modified test_df DataFrame
test_df

# %%
#test_df.to_csv('Submission_SVD.csv', index = False)

# %% [markdown]
# ### Why SVD?
#
# *
